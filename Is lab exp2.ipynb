# %% [markdown]
# Ex 2 INTEGRITY

# %%
import hashlib

def compute_md5_hash():
    text = input("Enter a string:\n")
    result = hashlib.md5(text.encode())
    print("The byte equivalent of hash is:", result.digest())
    print("The hexadecimal hash is:", result.hexdigest())

def display_algorithms():
    print("The available algorithms are:", hashlib.algorithms_guaranteed)

def main():
    compute_md5_hash()
    display_algorithms()

if __name__ == "__main__":
    main()
# Out:
# Enter a string:
# jupyter
# The byte equivalent of hash is: b'\x9f;\xc3\x08\x08\xfb\xfc\x0ff\xde8}Wj\t='
# The hexadecimal hash is: 9f3bc30808fbfc0f66de387d576a093d
# The available algorithms are: {'sha384', 'sha3_384', 'shake_256', 'md5', 'sha1', 'sha256', 'sha224', 'sha3_256', 'shake_128', 'sha3_224', 'sha3_512', 'blake2s', 'sha512', 'blake2b'}
